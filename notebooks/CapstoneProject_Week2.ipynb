# %%
import re
import bs4
import requests
import datetime
import pathlib

def download_pdfs(url_domain, url_path, url_sufix, save_path, year):
    # Set the URL, which changes depending on the year
    current_year = datetime.datetime.now().year
    url = url_domain + url_path
    if year != current_year:
        url += url_sufix + str(year)
        
    # Get the request from the bank URL
    website_request = requests.get(url)
    assert website_request.status_code == 200
    soup = bs4.BeautifulSoup(website_request.content)
    
    # Filter the HTML tags into only PDF links
    a_tags = soup.findAll('a')
    pdf_tags = list(filter(lambda a_tag : a_tag.text == 'PDF' , a_tags))
    
    # Create the PDF saving path if it doesn't exist
    save_path += f'/{year}'
    pathlib.Path(save_path).mkdir(parents=True, exist_ok=True)
    print(f'Starting to download {len(pdf_tags)} PDFs from {year} ({url_domain})...')
    
    # Loop through the PDFs and save them into the save path
    for i in range(len(pdf_tags)):
        
        # Set the pdf url extracted from the href attribute from a tags
        url_pdf = pdf_tags[i]['href']
        if not url_pdf.startswith('http'):
            url_pdf = url_domain + url_pdf
        
        # Request the PDF file and save it
        pdf_request = requests.get(url_pdf)
        assert pdf_request.status_code == 200
        pdf_file = open(save_path + f'/TD{year}_{i+1}.pdf', 'wb')
        pdf_file.write(pdf_request.content)
        pdf_file.close()
        
    print(f'Download successful: {len(pdf_tags)} PDFs from {year} ({url_domain})')

# %%
DOMAIN = "https://www.td.com"
URL = "/ca/en/about-td/for-investors/investor-relations/financial-information/financial-reports/quarterly-results"
URL_SUFIX = "/quarterly-results-"
SAVE_PATH = 'TDBank/'

download_pdfs(DOMAIN, URL, URL_SUFIX, SAVE_PATH, 1999)
# Out:
# Starting to download 7 PDFs from 1999 (https://www.td.com)...
# Download successful: 7 PDFs from 1999 (https://www.td.com)

# %%
import os
url = "https://www.td.com/ca/en/about-td/for-investors/investor-relations/financial-information/financial-reports/quarterly-results"

folder_location = 'data/pdf_files'
if not os.path.exists(folder_location):
    os.mkdir(folder_location)

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")     
for link in soup.select("a[href$='.pdf']"):
    filename = os.path.join(folder_location, link['href'].split('/')[-1])
    with open(filename, 'wb') as f:
        f.write(requests.get(urljoin(url, link['href'])).content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[92], line 6
#       4 folder_location = 'data/pdf_files'
#       5 if not os.path.exists(folder_location):
# ----> 6     os.mkdir(folder_location)
#       8 response = requests.get(url)
#       9 soup = BeautifulSoup(response.text, "html.parser")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/pdf_files'

# %%
from bs4 import BeautifulSoup
import requests

#link to all the documents for ScotiaBank 
link = 'https://www.scotiabank.com/ca/en/about/investors-shareholders/annual-reports.html'
data_path = '../data/Scotia/'

# %%
def get_pdf_url(url):
    # data_folder = os.path.join(data_folder,year)
    # if not os.path.exists(data_folder):
    #     os.makedirs(data_folder)
    base_url = re.findall(r'^.+?[^\/:](?=[?\/]|$)',url)[0]
    r = requests.get(url)
    if r.status_code == 200:
        soup = BeautifulSoup(r.content)
        links =  soup.findAll('a')
        links = [link.attrs['href'] for link in links if 'href' in link.attrs.keys() and link.attrs['href'].endswith('.pdf')]
        links = [link if link.startswith('http') else base_url+link for link in links]
        return set(links)

# %%
url = 'https://www.cibc.com/en/about-cibc/investor-relations/quarterly-results.html'
len(get_pdf_url(url))
# Out:
# 638

# %%
def get_all_pdfs(url):
    # data_folder = os.path.join(data_folder,year)
    # if not os.path.exists(data_folder):
    #     os.makedirs(data_folder)
    base_url = re.findall(r'^.+?[^\/:](?=[?\/]|$)',url)[0]
    r = requests.get(url)
    if r.status_code == 200:
        soup = BeautifulSoup(r.content)
        links =  soup.findAll('a')
        pdfs = set()
        others = set()
        for link in links:
            if 'href' in link.attrs.keys():
                link = link.attrs['href']
                if not link.startswith('http'):
                    link = base_url + link
                if link.endswith('.pdf'):
                    print(link)
                    pdfs.add(link)
                else:
                    others.add(link)
        for other in others:
            try:
                out_pdf = get_pdf_url(other) if other.startswith(base_url) else 0
                
                if out_pdf:
                    pdfs.update(out_pdf)
            except TimeoutError:
                    print(link)
    else:
            pass
    print(len(pdfs))
    return pdfs
        
a = get_all_pdfs(url)
a
# Out:
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q324hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q224-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2024/q124-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/ar-23-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q423-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q323-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q223-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/q123-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/ar-22-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q422-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q322-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q222-transcript-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122report-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122newsrelease-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122dividend-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122financials-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122disclosure-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122presentation-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122factsheet-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122hlts-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2022/q122-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/ar-21-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q421-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q321-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q221-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2021/q121-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/ar-20-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420financials-restated-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q420-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q320-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q220-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/cibc-oil-and-gas-update-march-2020-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2020/q120-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/ar-19-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q419-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q319-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q219-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2019/q119-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/ar-18-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q4-2018-cibc-faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q418-transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q318transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q218transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2018/q118transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217financials-restated-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317financials-restated-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/ifrs9financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417transcript-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q117hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q217hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q317hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2017/q417hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416newsrelease-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416dividend-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316report-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416financials-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416disclosure-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416presentation-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416factsheet-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q116hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q216hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q316hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2016/q416hlts-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415financials-restated.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q115hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q215hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q315hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2015/q415hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414disclosure.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q114hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q214hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q314hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2014/q414hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413financials-restated.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q113hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q213hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q313hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2013/q413hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q112newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q212newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q312newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q412newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q112dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q212dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2012/q312dividend.pdf
# ...
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2008/q308faq.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2008/q408faq.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407factsheet.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q107faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q207faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q307faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2007/q407faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q106faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q206faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q306faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2006/q406faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405newsrelease.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405dividend.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305report.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405financials.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405presentation.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q105hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q205hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405hlts.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q305faq-en.pdf
# https://www.cibc.com/content/dam/about_cibc/investor_relations/pdfs/quarterly_results/2005/q405faq-en.pdf
# https://www.cibc.com/content/dam/cibc-public-assets/about-cibc/investor-relations/pdfs/quarterly-results/2023/ar-23-en.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 35
#      32     print(len(pdfs))
#      33     return pdfs
# ---> 35 a = get_all_pdfs(url)
#      36 a
#
# Cell In[4], line 24, in get_all_pdfs(url)
#      22 for other in others:
#      23     try:
# ---> 24         out_pdf = get_pdf_url(other) if other.startswith(base_url) else 0
#      26         if out_pdf:
#      27             pdfs.update(out_pdf)
#
# Cell In[2], line 6, in get_pdf_url(url)
#       1 def get_pdf_url(url):
#       2     # data_folder = os.path.join(data_folder,year)
#       3     # if not os.path.exists(data_folder):
#       4     #     os.makedirs(data_folder)
#       5     base_url = re.findall(r'^.+?[^\/:](?=[?\/]|$)',url)[0]
# ----> 6     r = requests.get(url)
#       7     if r.status_code == 200:
#       8         soup = BeautifulSoup(r.content)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:
